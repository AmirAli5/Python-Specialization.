# %% [markdown]
# # Modules

# %% [markdown]
# ### import Modules

# %%
# 1st way
import random 
random.randint(1,100)
# Out:
# 83

# %%
# 2nd way
import random as randint
random.randint(1,100)
# Out:
# 74

# %%
# third way
import random as r
r.randint(1,100)
# Out:
# 48

# %%
# 4th way
from random import randint
randint(1,100)
# Out:
# 7

# %%
# 5th way
from random import randint as r
r(1,100)
# Out:
# 3

# %% [markdown]
# ### custom module

# %% [markdown]
# this is basically made by delveloper smilary when i used apriori algoruthm and ssd algorithm import the ssd.py files

# %% [markdown]
# ### External Modules

# %%
import termcolor    # this external module we use to download from cmd using pip or conda like numpy etc

# %%
help(termcolor)     # information about package use help
# Out:
# Help on module termcolor:
#
# NAME
#     termcolor - ANSII Color formatting for output in terminal.
#
# FUNCTIONS
#     colored(text, color=None, on_color=None, attrs=None)
#         Colorize text.
#
#         Available text colors:
#             red, green, yellow, blue, magenta, cyan, white.
#
#         Available text highlights:
#             on_red, on_green, on_yellow, on_blue, on_magenta, on_cyan, on_white.
#
#         Available attributes:
#             bold, dark, underline, blink, reverse, concealed.
#
#         Example:
#             colored('Hello, World!', 'red', 'on_grey', ['blue', 'blink'])
#             colored('Hello, World!', 'green')
#
#     cprint(text, color=None, on_color=None, attrs=None, **kwargs)
#         Print colorize text.
#
#         It accepts arguments of print function.
#
# DATA
#     ATTRIBUTES = {'blink': 5, 'bold': 1, 'concealed': 8, 'dark': 2, 'rever...
#     COLORS = {'blue': 34, 'cyan': 36, 'green': 32, 'grey': 30, 'magenta': ...
# ...

# %%
dir(termcolor)    # information about attribute of of given packg using dir
# Out:
# ['ATTRIBUTES',
#  'COLORS',
#  'HIGHLIGHTS',
#  'RESET',
#  'VERSION',
#  '__ALL__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'colored',
#  'cprint',
#  'os',
#  'print_function']

# %%
from termcolor import colored
text=colored("Amir Ali", color='red', on_color='on_yellow')
print(text)
# Out:
# Amir Ali

# %% [markdown]
# ### ASCII ART Exercise

# %%
import pyfiglet
help(pyfiglet)
# Out:
# Help on package pyfiglet:
#
# NAME
#     pyfiglet - Python FIGlet adaption
#
# PACKAGE CONTENTS
#     __main__
#     fonts (package)
#     test
#     version
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         FigletError
#             CharNotPrinted
#             FontError
#             FontNotFound
#             InvalidColor
#     builtins.object
#         Figlet
#         FigletBuilder
#         FigletFont
#         FigletProduct
#         FigletRenderingEngine
#     builtins.str(builtins.object)
#         FigletString
#
#     class CharNotPrinted(FigletError)
#      |  Raised when the width is not sufficient to print a character
#      |
#      |  Method resolution order:
#      |      CharNotPrinted
#      |      FigletError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods inherited from FigletError:
#      |
#      |  __init__(self, error)
# ...

# %%
result=pyfiglet.figlet_format("hi")

# %%
result
# Out:
# " _     _ \n| |__ (_)\n| '_ \\| |\n| | | | |\n|_| |_|_|\n         \n"

# %%
print(result)
# Out:
#  _     _
# | |__ (_)
# | '_ \| |
# | | | | |
# |_| |_|_|
